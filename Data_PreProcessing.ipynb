# %%
import os
import random
import librosa
import numpy as np
import soundfile as sf
from pydub import AudioSegment
from pydub.playback import play
import matplotlib.pyplot as plt

# %%
def calculate_SNR(clean_signal, noisy_signal):
    # Ensure both signals have the same length
    min_length = min(len(clean_signal), len(noisy_signal))
    clean_signal = clean_signal[:min_length]
    noisy_signal = noisy_signal[:min_length]
    
    # Calculate energy
    clean_energy = np.sum(clean_signal ** 2)
    noise_energy = np.sum((clean_signal - noisy_signal) ** 2)
    
    # Calculate SNR
    snr = 10 * np.log10(clean_energy / noise_energy)
    return snr

# %%
# Initialize lists to store audio data and labels
audio_data = []  # Initialize audio data list
total_input_files = 0
total_output_files = 0

# %%
# Input and Output directory
input_directory = 'D:\\Sem4\\Data_298B_Project\\Input'
output_directory = 'D:\\Sem4\\Data_298B_Project\\Output'

# %%
# Iterate through each subfolder in the input directory
for subdir, dirs, files in os.walk(input_directory):
    input_files_count = 0
    output_files_count = 0
    for file in files:
        if file.endswith('.wav'):
            input_files_count += 1
            total_input_files += 1
            # Construct the full file path for input
            input_file_path = os.path.join(subdir, file)

            # Construct the corresponding output subdirectory path
            output_subdir_path = subdir.replace(input_directory, output_directory)
            if not os.path.exists(output_subdir_path):
                os.makedirs(output_subdir_path)
            # Load the audio file for Data Synthesis using pydub library
            audio_py = AudioSegment.from_file(input_file_path)
        
            min_duration_ms = 500  # Minimum duration in milliseconds
        
            if len(audio_py) < min_duration_ms:
                # Calculate how much silence needs to be added
                silence_duration = min_duration_ms - len(audio_py)
                # Create a silent audio segment of the required duration
                silence_segment = AudioSegment.silent(duration=silence_duration)
                # Append the silent segment to the audio to meet the minimum duration requirement
                audio_py = audio_py + silence_segment

            # Audio processing with pydub
            audio_faster = audio_py.speedup(playback_speed=1.5)
            audio_slower = audio_py.speedup(playback_speed=0.75)
            audio_reversed = audio_py.reverse()
            # Random pitch shift (within a range)
            octaves = random.uniform(-0.5, 0.5)
            new_sample_rate = int(audio_py.frame_rate * (2 ** octaves))
            audio_pitch_shifted = audio_py._spawn(audio_py.raw_data, overrides={'frame_rate': new_sample_rate})
            audio_pitch_shifted = audio_pitch_shifted.set_frame_rate(audio_py.frame_rate)

            # Load the audio file for Data Augmentation using librosa library
            audio_lr, sr = librosa.load(input_file_path, sr=None)

            # Audio processing with librosa
            audio_stretched = librosa.effects.time_stretch(audio_lr, rate=1.25)
            audio_shifted = librosa.effects.pitch_shift(audio_lr, sr=sr, n_steps=4)
            audio_noisy = audio_lr + 0.005 * np.random.randn(len(audio_lr))

            audio_data.append(audio_lr)

            # Extract the base name without the extension for the input file
            base_name = os.path.splitext(file)[0]
            
            # Define the output filenames based on the input filename
            output_paths = {
                'faster': os.path.join(output_subdir_path, f'{base_name}_faster.wav'),
                'slower': os.path.join(output_subdir_path, f'{base_name}_slower.wav'),
                'reversed': os.path.join(output_subdir_path, f'{base_name}_reversed.wav'),
                'pitch_shifted': os.path.join(output_subdir_path, f'{base_name}_pitch_shifted.wav'),
                'stretched': os.path.join(output_subdir_path, f'{base_name}_stretched.wav'),
                'shifted': os.path.join(output_subdir_path, f'{base_name}_shifted.wav'),
                'noisy': os.path.join(output_subdir_path, f'{base_name}_noisy.wav')
            }

            # Save the transformed audio to new WAV files
            audio_faster.export(output_paths['faster'], format="wav")
            audio_slower.export(output_paths['slower'], format="wav")
            audio_reversed.export(output_paths['reversed'], format="wav")
            audio_pitch_shifted.export(output_paths['pitch_shifted'], format="wav")
            sf.write(output_paths['stretched'], audio_stretched, sr)
            sf.write(output_paths['shifted'], audio_shifted, sr)
            sf.write(output_paths['noisy'], audio_noisy, sr)

            # Increment output files count for each file processed
            output_files_count += len(output_paths)
            total_output_files += len(output_paths)

            # Evaluate the augmented and synthesized audio files
            for key in output_paths:
                clean_audio, sr = librosa.load(input_file_path, sr=None)
                # Load augmented audio for SNR calculation
                augmented_audio, _ = librosa.load(output_paths[key], sr=sr)
                clean_len = len(clean_audio)
                augmented_len = len(augmented_audio)
                if augmented_len < clean_len:
                    augmented_audio = np.pad(augmented_audio, (0, clean_len - augmented_len), mode='constant')
                elif augmented_len > clean_len:
                    augmented_audio = augmented_audio[:clean_len]
                print("Length of clean audio:", len(clean_audio))
                print("Length of augmented audio:", len(augmented_audio))
                # Calculate SNR
                snr = calculate_SNR(clean_audio, augmented_audio)
                print(f"SNR for {key} file '{output_paths[key]}': {snr} dB")
                # Save the augmented audio to output directory only if SNR is greater than 0 dB
                if snr > 0:
                    output_file_path = output_paths[key]
                    sf.write(output_file_path, augmented_audio, sr)
                    print(f"Augmented audio saved to '{output_file_path}'")
                else:
                    print(f"SNR for {key} file '{output_paths[key]}' is below 0 dB. Augmented audio not saved.")

# Print the total number of files processed
print(f"Total files after data augmentation and synthesis: {total_input_files + total_output_files} ")

print("All files have been processed and saved to the output directory.")
# Out:
# Length of clean audio: 65441
# Length of augmented audio: 65441
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_1_faster.wav': -2.459154725074768 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_1_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 65441
# Length of augmented audio: 65441
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_1_slower.wav': -1.2919066846370697 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_1_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 65441
# Length of augmented audio: 65441
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_1_reversed.wav': -2.928105592727661 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_1_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 65441
# Length of augmented audio: 65441
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_1_pitch_shifted.wav': -3.113108277320862 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_1_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 65441
# Length of augmented audio: 65441
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_1_stretched.wav': -1.269557923078537 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_1_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 65441
# Length of augmented audio: 65441
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_1_shifted.wav': -1.4815853536128998 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_1_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 65441
# Length of augmented audio: 65441
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_1_noisy.wav': 7.946211099624634 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_1_noisy.wav'
# Length of clean audio: 14625
# Length of augmented audio: 14625
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_10_faster.wav': 3.974020779132843 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_10_faster.wav'
# Length of clean audio: 14625
# Length of augmented audio: 14625
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_10_slower.wav': 0.07360640913248062 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_10_slower.wav'
# Length of clean audio: 14625
# Length of augmented audio: 14625
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_10_reversed.wav': -1.4202423393726349 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_10_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 14625
# Length of augmented audio: 14625
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_10_pitch_shifted.wav': -3.6217284202575684 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_10_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 14625
# Length of augmented audio: 14625
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_10_stretched.wav': -0.022534371819347143 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_10_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 14625
# Length of augmented audio: 14625
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_10_shifted.wav': -2.543901205062866 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_10_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 14625
# Length of augmented audio: 14625
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_10_noisy.wav': 10.249096155166626 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_10_noisy.wav'
# Length of clean audio: 12442
# Length of augmented audio: 12442
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_11_faster.wav': 8.752256631851196 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_11_faster.wav'
# Length of clean audio: 12442
# Length of augmented audio: 12442
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_11_slower.wav': 2.2802960872650146 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_11_slower.wav'
# Length of clean audio: 12442
# Length of augmented audio: 12442
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_11_reversed.wav': -0.0008504373545292765 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_11_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 12442
# Length of augmented audio: 12442
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_11_pitch_shifted.wav': -2.7221882343292236 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_11_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 12442
# Length of augmented audio: 12442
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_11_stretched.wav': 2.0856235921382904 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_11_stretched.wav'
# Length of clean audio: 12442
# Length of augmented audio: 12442
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_11_shifted.wav': -1.83563694357872 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_11_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 12442
# Length of augmented audio: 12442
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_11_noisy.wav': 10.136265754699707 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_11_noisy.wav'
# Length of clean audio: 13582
# Length of augmented audio: 13582
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_12_faster.wav': 2.6425522565841675 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_12_faster.wav'
# Length of clean audio: 13582
# Length of augmented audio: 13582
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_12_slower.wav': 1.095859706401825 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_12_slower.wav'
# Length of clean audio: 13582
# Length of augmented audio: 13582
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_12_reversed.wav': -1.345830112695694 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_12_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 13582
# Length of augmented audio: 13582
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_12_pitch_shifted.wav': -2.8735432028770447 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_12_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 13582
# Length of augmented audio: 13582
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_12_stretched.wav': 0.17064185813069344 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_12_stretched.wav'
# Length of clean audio: 13582
# Length of augmented audio: 13582
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_12_shifted.wav': -1.701766699552536 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_12_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 13582
# Length of augmented audio: 13582
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_12_noisy.wav': 11.451160907745361 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_12_noisy.wav'
# Length of clean audio: 15498
# Length of augmented audio: 15498
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_13_faster.wav': 3.3426201343536377 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_13_faster.wav'
# Length of clean audio: 15498
# Length of augmented audio: 15498
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_13_slower.wav': 0.5345850065350533 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_13_slower.wav'
# Length of clean audio: 15498
# Length of augmented audio: 15498
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_13_reversed.wav': -1.746048927307129 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_13_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 15498
# Length of augmented audio: 15498
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_13_pitch_shifted.wav': -3.2283568382263184 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_13_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 15498
# Length of augmented audio: 15498
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_13_stretched.wav': -0.2787594683468342 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_13_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 15498
# Length of augmented audio: 15498
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_13_shifted.wav': -1.0430575907230377 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_13_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 15498
# Length of augmented audio: 15498
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_13_noisy.wav': 8.673511743545532 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_13_noisy.wav'
# Length of clean audio: 29591
# Length of augmented audio: 29591
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_14_faster.wav': -0.8595488220453262 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_14_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 29591
# Length of augmented audio: 29591
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_14_slower.wav': -0.22964421659708023 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_14_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 29591
# Length of augmented audio: 29591
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_14_reversed.wav': -2.9727986454963684 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_14_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 29591
# Length of augmented audio: 29591
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_14_pitch_shifted.wav': -3.307976722717285 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_14_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 29591
# Length of augmented audio: 29591
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_14_stretched.wav': -0.6583861261606216 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_14_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 29591
# Length of augmented audio: 29591
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_14_shifted.wav': -1.6201332211494446 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_14_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 29591
# Length of augmented audio: 29591
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_14_noisy.wav': 11.231217384338379 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_14_noisy.wav'
# Length of clean audio: 28034
# Length of augmented audio: 28034
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_15_faster.wav': -2.2182345390319824 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_15_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 28034
# Length of augmented audio: 28034
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_15_slower.wav': -1.042575165629387 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_15_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 28034
# Length of augmented audio: 28034
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_15_reversed.wav': -2.8832393884658813 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_15_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 28034
# Length of augmented audio: 28034
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_15_pitch_shifted.wav': -2.593677043914795 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_15_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 28034
# Length of augmented audio: 28034
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_15_stretched.wav': -1.064952239394188 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_15_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 28034
# Length of augmented audio: 28034
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_15_shifted.wav': -1.5640239417552948 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_15_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 28034
# Length of augmented audio: 28034
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_15_noisy.wav': 9.698336720466614 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_15_noisy.wav'
# Length of clean audio: 21544
# Length of augmented audio: 21544
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_16_faster.wav': 2.221556305885315 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_16_faster.wav'
# Length of clean audio: 21544
# Length of augmented audio: 21544
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_16_slower.wav': -0.03758264472708106 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_16_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 21544
# Length of augmented audio: 21544
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_16_reversed.wav': -3.0285972356796265 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_16_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 21544
# Length of augmented audio: 21544
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_16_pitch_shifted.wav': -2.6665666699409485 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_16_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 21544
# Length of augmented audio: 21544
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_16_stretched.wav': -0.21777577698230743 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_16_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 21544
# Length of augmented audio: 21544
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_16_shifted.wav': -1.7668527364730835 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_16_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 21544
# Length of augmented audio: 21544
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_16_noisy.wav': 6.076892614364624 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_16_noisy.wav'
# Length of clean audio: 18722
# Length of augmented audio: 18722
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_17_faster.wav': 0.8756513148546219 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_17_faster.wav'
# Length of clean audio: 18722
# Length of augmented audio: 18722
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_17_slower.wav': -0.8820638060569763 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_17_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 18722
# Length of augmented audio: 18722
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_17_reversed.wav': -3.888714015483856 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_17_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 18722
# Length of augmented audio: 18722
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_17_pitch_shifted.wav': -3.2281753420829773 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_17_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 18722
# Length of augmented audio: 18722
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_17_stretched.wav': 0.06764884572476149 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_17_stretched.wav'
# Length of clean audio: 18722
# Length of augmented audio: 18722
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_17_shifted.wav': 0.06134415976703167 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_17_shifted.wav'
# Length of clean audio: 18722
# Length of augmented audio: 18722
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_17_noisy.wav': 5.951882600784302 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_17_noisy.wav'
# Length of clean audio: 21827
# Length of augmented audio: 21827
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_18_faster.wav': -1.0902412980794907 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_18_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 21827
# Length of augmented audio: 21827
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_18_slower.wav': -0.4773719236254692 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_18_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 21827
# Length of augmented audio: 21827
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_18_reversed.wav': -3.3235514163970947 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_18_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 21827
# Length of augmented audio: 21827
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_18_pitch_shifted.wav': -3.10291588306427 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_18_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 21827
# Length of augmented audio: 21827
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_18_stretched.wav': -0.6295178085565567 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_18_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 21827
# Length of augmented audio: 21827
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_18_shifted.wav': -1.6256651282310486 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_18_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 21827
# Length of augmented audio: 21827
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_18_noisy.wav': 13.834562301635742 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_18_noisy.wav'
# Length of clean audio: 57712
# Length of augmented audio: 57712
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_2_faster.wav': -2.3616820573806763 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_2_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 57712
# Length of augmented audio: 57712
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_2_slower.wav': -0.4191960021853447 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_2_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 57712
# Length of augmented audio: 57712
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_2_reversed.wav': -3.1486332416534424 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_2_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 57712
# Length of augmented audio: 57712
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_2_pitch_shifted.wav': -2.982100546360016 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_2_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 57712
# Length of augmented audio: 57712
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_2_stretched.wav': -1.3592980802059174 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_2_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 57712
# Length of augmented audio: 57712
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_2_shifted.wav': -2.1402141451835632 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_2_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 57712
# Length of augmented audio: 57712
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_2_noisy.wav': 3.612741231918335 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_2_noisy.wav'
# Length of clean audio: 17904
# Length of augmented audio: 17904
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_3_faster.wav': 1.8186579644680023 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_3_faster.wav'
# Length of clean audio: 17904
# Length of augmented audio: 17904
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_3_slower.wav': 0.3043885715305805 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_3_slower.wav'
# Length of clean audio: 17904
# Length of augmented audio: 17904
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_3_reversed.wav': -2.29375422000885 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_3_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17904
# Length of augmented audio: 17904
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_3_pitch_shifted.wav': -2.684429883956909 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_3_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17904
# Length of augmented audio: 17904
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_3_stretched.wav': -0.05878208205103874 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_3_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17904
# Length of augmented audio: 17904
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_3_shifted.wav': -1.4314354956150055 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_3_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17904
# Length of augmented audio: 17904
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_3_noisy.wav': 12.107393741607666 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_3_noisy.wav'
# Length of clean audio: 37968
# Length of augmented audio: 37968
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_4_faster.wav': -1.5537120401859283 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_4_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 37968
# Length of augmented audio: 37968
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_4_slower.wav': -0.29328998178243637 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_4_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 37968
# Length of augmented audio: 37968
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_4_reversed.wav': -3.194149434566498 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_4_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 37968
# Length of augmented audio: 37968
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_4_pitch_shifted.wav': -3.436528444290161 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_4_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 37968
# Length of augmented audio: 37968
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_4_stretched.wav': -1.2332239001989365 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_4_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 37968
# Length of augmented audio: 37968
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_4_shifted.wav': -1.7883633077144623 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_4_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 37968
# Length of augmented audio: 37968
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_4_noisy.wav': 7.754706144332886 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_4_noisy.wav'
# Length of clean audio: 19273
# Length of augmented audio: 19273
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_5_faster.wav': -1.2979140877723694 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_5_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 19273
# Length of augmented audio: 19273
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_5_slower.wav': -0.9188319742679596 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_5_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 19273
# Length of augmented audio: 19273
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_5_reversed.wav': -3.427245318889618 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_5_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 19273
# Length of augmented audio: 19273
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_5_pitch_shifted.wav': -2.740900218486786 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_5_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 19273
# Length of augmented audio: 19273
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_5_stretched.wav': -0.9427344799041748 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_5_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 19273
# Length of augmented audio: 19273
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_5_shifted.wav': -1.5805532038211823 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_5_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 19273
# Length of augmented audio: 19273
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_5_noisy.wav': 10.162070989608765 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_5_noisy.wav'
# Length of clean audio: 30468
# Length of augmented audio: 30468
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_6_faster.wav': -2.4505536258220673 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_6_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 30468
# Length of augmented audio: 30468
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_6_slower.wav': -0.8186334371566772 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_6_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 30468
# Length of augmented audio: 30468
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_6_reversed.wav': -2.8399795293807983 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_6_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 30468
# Length of augmented audio: 30468
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_6_pitch_shifted.wav': -2.345123291015625 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_6_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 30468
# Length of augmented audio: 30468
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_6_stretched.wav': -0.954914465546608 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_6_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 30468
# Length of augmented audio: 30468
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_6_shifted.wav': -1.4044158160686493 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_6_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 30468
# Length of augmented audio: 30468
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_6_noisy.wav': 10.666195154190063 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_6_noisy.wav'
# Length of clean audio: 13949
# Length of augmented audio: 13949
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_7_faster.wav': 4.89265501499176 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_7_faster.wav'
# Length of clean audio: 13949
# Length of augmented audio: 13949
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_7_slower.wav': 0.5014781281352043 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_7_slower.wav'
# Length of clean audio: 13949
# Length of augmented audio: 13949
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_7_reversed.wav': -0.42281419038772583 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_7_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 13949
# Length of augmented audio: 13949
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_7_pitch_shifted.wav': -3.3837085962295532 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_7_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 13949
# Length of augmented audio: 13949
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_7_stretched.wav': 0.7262647151947021 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_7_stretched.wav'
# Length of clean audio: 13949
# Length of augmented audio: 13949
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_7_shifted.wav': -2.2254619002342224 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_7_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 13949
# Length of augmented audio: 13949
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_7_noisy.wav': 12.89379358291626 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_7_noisy.wav'
# Length of clean audio: 27531
# Length of augmented audio: 27531
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_8_faster.wav': -0.47087371349334717 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_8_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 27531
# Length of augmented audio: 27531
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_8_slower.wav': -0.17443424090743065 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_8_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 27531
# Length of augmented audio: 27531
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_8_reversed.wav': -2.9741057753562927 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_8_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 27531
# Length of augmented audio: 27531
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_8_pitch_shifted.wav': -2.2015194594860077 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_8_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 27531
# Length of augmented audio: 27531
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_8_stretched.wav': -1.6015982627868652 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_8_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 27531
# Length of augmented audio: 27531
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_8_shifted.wav': -1.6748054325580597 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_8_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 27531
# Length of augmented audio: 27531
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_8_noisy.wav': 10.768754482269287 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_8_noisy.wav'
# Length of clean audio: 26629
# Length of augmented audio: 26629
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_9_faster.wav': -0.7460539788007736 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_9_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 26629
# Length of augmented audio: 26629
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_9_slower.wav': -0.44050030410289764 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_9_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 26629
# Length of augmented audio: 26629
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_9_reversed.wav': -3.348063826560974 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_9_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 26629
# Length of augmented audio: 26629
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_9_pitch_shifted.wav': -3.2328474521636963 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_9_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 26629
# Length of augmented audio: 26629
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_9_stretched.wav': -0.03199353814125061 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_9_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 26629
# Length of augmented audio: 26629
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_9_shifted.wav': -2.3256289958953857 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_9_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 26629
# Length of augmented audio: 26629
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_9_noisy.wav': 14.226279258728027 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\African_Swine_Fever\sf_9_noisy.wav'
# Length of clean audio: 17389
# Length of augmented audio: 17389
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu23_faster.wav': -2.6348766684532166 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu23_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17389
# Length of augmented audio: 17389
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu23_slower.wav': -0.5876077339053154 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu23_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17389
# Length of augmented audio: 17389
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu23_reversed.wav': -3.0672428011894226 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu23_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17389
# Length of augmented audio: 17389
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu23_pitch_shifted.wav': -2.3463107645511627 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu23_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17389
# Length of augmented audio: 17389
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu23_stretched.wav': -1.3973172008991241 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu23_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17389
# Length of augmented audio: 17389
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu23_shifted.wav': -1.9949491322040558 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu23_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17389
# Length of augmented audio: 17389
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu23_noisy.wav': 22.40683078765869 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu23_noisy.wav'
# Length of clean audio: 48167
# Length of augmented audio: 48167
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_1_faster.wav': -0.5323958396911621 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_1_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 48167
# Length of augmented audio: 48167
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_1_slower.wav': -0.16284478828310966 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_1_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 48167
# Length of augmented audio: 48167
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_1_reversed.wav': -3.0969014763832092 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_1_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 48167
# Length of augmented audio: 48167
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_1_pitch_shifted.wav': -3.6990678310394287 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_1_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 48167
# Length of augmented audio: 48167
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_1_stretched.wav': -1.1756886541843414 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_1_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 48167
# Length of augmented audio: 48167
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_1_shifted.wav': -1.6083866357803345 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_1_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 48167
# Length of augmented audio: 48167
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_1_noisy.wav': 18.172998428344727 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_1_noisy.wav'
# Length of clean audio: 17473
# Length of augmented audio: 17473
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_10_faster.wav': 4.028794467449188 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_10_faster.wav'
# Length of clean audio: 17473
# Length of augmented audio: 17473
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_10_slower.wav': -0.16410164535045624 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_10_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17473
# Length of augmented audio: 17473
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_10_reversed.wav': -2.8250709176063538 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_10_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17473
# Length of augmented audio: 17473
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_10_pitch_shifted.wav': -3.3598342537879944 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_10_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17473
# Length of augmented audio: 17473
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_10_stretched.wav': -0.701214149594307 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_10_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17473
# Length of augmented audio: 17473
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_10_shifted.wav': -1.2161756306886673 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_10_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17473
# Length of augmented audio: 17473
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_10_noisy.wav': 10.583924055099487 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_10_noisy.wav'
# Length of clean audio: 35373
# Length of augmented audio: 35373
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_11_faster.wav': -1.8547441065311432 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_11_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 35373
# Length of augmented audio: 35373
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_11_slower.wav': -1.3806284964084625 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_11_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 35373
# Length of augmented audio: 35373
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_11_reversed.wav': -2.9910844564437866 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_11_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 35373
# Length of augmented audio: 35373
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_11_pitch_shifted.wav': -3.273957371711731 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_11_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 35373
# Length of augmented audio: 35373
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_11_stretched.wav': -1.445818692445755 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_11_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 35373
# Length of augmented audio: 35373
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_11_shifted.wav': -1.9667422771453857 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_11_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 35373
# Length of augmented audio: 35373
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_11_noisy.wav': 19.52195167541504 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_11_noisy.wav'
# Length of clean audio: 34828
# Length of augmented audio: 34828
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_12_faster.wav': -2.5562986731529236 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_12_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 34828
# Length of augmented audio: 34828
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_12_slower.wav': -0.3802017495036125 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_12_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 34828
# Length of augmented audio: 34828
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_12_reversed.wav': -2.972213625907898 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_12_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 34828
# Length of augmented audio: 34828
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\Pneumonia\pnu_12_pitch_shifted.wav': -3.4168288111686707 dB
# ...
# Length of clean audio: 22470
# Length of augmented audio: 22470
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_17_noisy.wav': 22.928457260131836 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_17_noisy.wav'
# Length of clean audio: 18689
# Length of augmented audio: 18689
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_2_faster.wav': 1.2381526082754135 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_2_faster.wav'
# Length of clean audio: 18689
# Length of augmented audio: 18689
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_2_slower.wav': -0.056131728924810886 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_2_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 18689
# Length of augmented audio: 18689
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_2_reversed.wav': -2.8675857186317444 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_2_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 18689
# Length of augmented audio: 18689
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_2_pitch_shifted.wav': -3.089590072631836 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_2_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 18689
# Length of augmented audio: 18689
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_2_stretched.wav': -0.9066375344991684 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_2_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 18689
# Length of augmented audio: 18689
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_2_shifted.wav': -1.7242442071437836 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_2_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 18689
# Length of augmented audio: 18689
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_2_noisy.wav': 23.90110969543457 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_2_noisy.wav'
# Length of clean audio: 17631
# Length of augmented audio: 17631
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_3_faster.wav': -0.48700589686632156 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_3_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17631
# Length of augmented audio: 17631
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_3_slower.wav': 0.3533068299293518 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_3_slower.wav'
# Length of clean audio: 17631
# Length of augmented audio: 17631
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_3_reversed.wav': -2.586420774459839 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_3_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17631
# Length of augmented audio: 17631
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_3_pitch_shifted.wav': -3.3453792333602905 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_3_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17631
# Length of augmented audio: 17631
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_3_stretched.wav': -0.7147116959095001 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_3_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17631
# Length of augmented audio: 17631
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_3_shifted.wav': -1.7324861884117126 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_3_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 17631
# Length of augmented audio: 17631
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_3_noisy.wav': 22.368061542510986 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_3_noisy.wav'
# Length of clean audio: 14692
# Length of augmented audio: 14692
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_4_faster.wav': 2.111358940601349 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_4_faster.wav'
# Length of clean audio: 14692
# Length of augmented audio: 14692
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_4_slower.wav': 0.07737049832940102 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_4_slower.wav'
# Length of clean audio: 14692
# Length of augmented audio: 14692
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_4_reversed.wav': -1.8343912065029144 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_4_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 14692
# Length of augmented audio: 14692
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_4_pitch_shifted.wav': -2.953110933303833 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_4_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 14692
# Length of augmented audio: 14692
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_4_stretched.wav': -0.8759695291519165 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_4_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 14692
# Length of augmented audio: 14692
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_4_shifted.wav': -1.5663240849971771 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_4_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 14692
# Length of augmented audio: 14692
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_4_noisy.wav': 21.987590789794922 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_4_noisy.wav'
# Length of clean audio: 16713
# Length of augmented audio: 16713
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_5_faster.wav': -0.370321162045002 dB
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_5_faster.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 16713
# Length of augmented audio: 16713
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_5_slower.wav': -0.10038859210908413 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_5_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 16713
# Length of augmented audio: 16713
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_5_reversed.wav': -3.0498504638671875 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_5_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 16713
# Length of augmented audio: 16713
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_5_pitch_shifted.wav': -3.3332690596580505 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_5_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 16713
# Length of augmented audio: 16713
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_5_stretched.wav': -1.5657664835453033 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_5_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 16713
# Length of augmented audio: 16713
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_5_shifted.wav': -1.8295778334140778 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_5_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 16713
# Length of augmented audio: 16713
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_5_noisy.wav': 22.46809959411621 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_5_noisy.wav'
# Length of clean audio: 19467
# Length of augmented audio: 19467
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_6_faster.wav': 5.762304067611694 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_6_faster.wav'
# Length of clean audio: 19467
# Length of augmented audio: 19467
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_6_slower.wav': -0.1545351929962635 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_6_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 19467
# Length of augmented audio: 19467
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_6_reversed.wav': -2.9500621557235718 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_6_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 19467
# Length of augmented audio: 19467
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_6_pitch_shifted.wav': -2.524983584880829 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_6_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 19467
# Length of augmented audio: 19467
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_6_stretched.wav': -1.2384393066167831 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_6_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 19467
# Length of augmented audio: 19467
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_6_shifted.wav': -1.6994352638721466 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_6_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 19467
# Length of augmented audio: 19467
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_6_noisy.wav': 24.460458755493164 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_6_noisy.wav'
# Length of clean audio: 24610
# Length of augmented audio: 24610
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_7_faster.wav': 0.8539436757564545 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_7_faster.wav'
# Length of clean audio: 24610
# Length of augmented audio: 24610
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_7_slower.wav': -0.48012204468250275 dB
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_7_slower.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 24610
# Length of augmented audio: 24610
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_7_reversed.wav': -3.1115785241127014 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_7_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 24610
# Length of augmented audio: 24610
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_7_pitch_shifted.wav': -3.1861698627471924 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_7_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 24610
# Length of augmented audio: 24610
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_7_stretched.wav': -1.232040524482727 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_7_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 24610
# Length of augmented audio: 24610
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_7_shifted.wav': -1.6209527850151062 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_7_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 24610
# Length of augmented audio: 24610
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_7_noisy.wav': 21.979310512542725 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_7_noisy.wav'
# Length of clean audio: 15244
# Length of augmented audio: 15244
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_8_faster.wav': 2.9418393969535828 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_8_faster.wav'
# Length of clean audio: 15244
# Length of augmented audio: 15244
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_8_slower.wav': 0.0005823952233185992 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_8_slower.wav'
# Length of clean audio: 15244
# Length of augmented audio: 15244
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_8_reversed.wav': -1.5966299176216125 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_8_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 15244
# Length of augmented audio: 15244
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_8_pitch_shifted.wav': -2.386818826198578 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_8_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 15244
# Length of augmented audio: 15244
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_8_stretched.wav': -0.5507855117321014 dB
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_8_stretched.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 15244
# Length of augmented audio: 15244
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_8_shifted.wav': -2.0020791888237 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_8_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 15244
# Length of augmented audio: 15244
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_8_noisy.wav': 26.147520542144775 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_8_noisy.wav'
# Length of clean audio: 18366
# Length of augmented audio: 18366
# SNR for faster file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_9_faster.wav': 6.963300108909607 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_9_faster.wav'
# Length of clean audio: 18366
# Length of augmented audio: 18366
# SNR for slower file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_9_slower.wav': 0.869729071855545 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_9_slower.wav'
# Length of clean audio: 18366
# Length of augmented audio: 18366
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_9_reversed.wav': -2.4222446978092194 dB
# SNR for reversed file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_9_reversed.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 18366
# Length of augmented audio: 18366
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_9_pitch_shifted.wav': -3.1035268306732178 dB
# SNR for pitch_shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_9_pitch_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 18366
# Length of augmented audio: 18366
# SNR for stretched file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_9_stretched.wav': 0.10151360183954239 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_9_stretched.wav'
# Length of clean audio: 18366
# Length of augmented audio: 18366
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_9_shifted.wav': -1.5379752218723297 dB
# SNR for shifted file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_9_shifted.wav' is below 0 dB. Augmented audio not saved.
# Length of clean audio: 18366
# Length of augmented audio: 18366
# SNR for noisy file 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_9_noisy.wav': 22.446308135986328 dB
# Augmented audio saved to 'D:\Sem4\Data_298B_Project\Output\PRRS\prrs_9_noisy.wav'
# Total files after data augmentation and synthesis: 1080
# All files have been processed and saved to the output directory.
